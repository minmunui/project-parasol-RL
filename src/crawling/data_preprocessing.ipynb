# %%
import data_preprocessing as data_pre
import pandas as pd

# %%
df = pd.read_csv('data/norm_final_sk_hynix.csv')
df
# Out:
#             Date   Close   등락률    PER   PBR     회전율           환율      코스피  \
# 0     2014-01-02   35550 -3.40      -  2.53  0.0063  1050.750000  1967.19
# 1     2014-01-03   36300  2.11      -  2.59  0.0054  1049.599976  1946.14
# 2     2014-01-06   37650  3.72      -  2.68  0.0077  1053.800049  1953.28
# 3     2014-01-07   37800  0.40      -  2.69  0.0047  1065.400024  1959.44
# 4     2014-01-08   39000  3.17      -  2.78  0.0092  1068.500000  1958.96
# ...          ...     ...   ...    ...   ...     ...          ...      ...
# 2271  2023-07-18  117800  0.51  36.34  1.28  0.0032  1265.449951  2607.62
# 2272  2023-07-19  117500 -0.25  36.24  1.28  0.0035  1264.939941  2608.24
# 2273  2023-07-20  116900 -0.51  36.06  1.27  0.0027  1265.089966  2600.23
# 2274  2023-07-21  115100 -1.54  35.50  1.25  0.0038  1278.400024  2609.76
# 2275  2023-07-24  114000 -0.96  35.16  1.24  0.0038  1285.650024  2628.53
#
#        나스닥
# 0    -0.80
# 1    -0.27
# 2    -0.44
# 3     0.96
# 4     0.30
# ...

# %%
data_pre.addQuantyColumns(df, [5, 10, 30, 60, 120], '회전율', 'Close')
# Out:
#             Date   Close   등락률    PER   PBR     회전율           환율      코스피  \
# 0     2014-01-02   35550 -3.40      -  2.53  0.0063  1050.750000  1967.19
# 1     2014-01-03   36300  2.11      -  2.59  0.0054  1049.599976  1946.14
# 2     2014-01-06   37650  3.72      -  2.68  0.0077  1053.800049  1953.28
# 3     2014-01-07   37800  0.40      -  2.69  0.0047  1065.400024  1959.44
# 4     2014-01-08   39000  3.17      -  2.78  0.0092  1068.500000  1958.96
# ...          ...     ...   ...    ...   ...     ...          ...      ...
# 2271  2023-07-18  117800  0.51  36.34  1.28  0.0032  1265.449951  2607.62
# 2272  2023-07-19  117500 -0.25  36.24  1.28  0.0035  1264.939941  2608.24
# 2273  2023-07-20  116900 -0.51  36.06  1.27  0.0027  1265.089966  2600.23
# 2274  2023-07-21  115100 -1.54  35.50  1.25  0.0038  1278.400024  2609.76
# 2275  2023-07-24  114000 -0.96  35.16  1.24  0.0038  1285.650024  2628.53
#
#        나스닥  전일대비거래량비율  5일평균거래량비율  5일평균종가비율  10일평균거래량비율  10일평균종가비율  30일평균거래량비율  \
# ...

# %%
df
# Out:
#             Date   Close   등락률    PER   PBR     회전율           환율      코스피  \
# 0     2014-01-02   35550 -3.40      -  2.53  0.0063  1050.750000  1967.19
# 1     2014-01-03   36300  2.11      -  2.59  0.0054  1049.599976  1946.14
# 2     2014-01-06   37650  3.72      -  2.68  0.0077  1053.800049  1953.28
# 3     2014-01-07   37800  0.40      -  2.69  0.0047  1065.400024  1959.44
# 4     2014-01-08   39000  3.17      -  2.78  0.0092  1068.500000  1958.96
# ...          ...     ...   ...    ...   ...     ...          ...      ...
# 2271  2023-07-18  117800  0.51  36.34  1.28  0.0032  1265.449951  2607.62
# 2272  2023-07-19  117500 -0.25  36.24  1.28  0.0035  1264.939941  2608.24
# 2273  2023-07-20  116900 -0.51  36.06  1.27  0.0027  1265.089966  2600.23
# 2274  2023-07-21  115100 -1.54  35.50  1.25  0.0038  1278.400024  2609.76
# 2275  2023-07-24  114000 -0.96  35.16  1.24  0.0038  1285.650024  2628.53
#
#        나스닥  전일대비거래량비율  5일평균거래량비율  5일평균종가비율  10일평균거래량비율  10일평균종가비율  30일평균거래량비율  \
# ...
